# %%
import pandas as pd
import seaborn as sns

statistics = pd.read_csv('results/benchmark_results-2025-11-10_12-03-41.csv')

# %%
sns.barplot(
    statistics, 
    y='function', 
    x='median_time',
    hue='n_returns', 
    log_scale=False
)
# Out:
# <Axes: xlabel='median_time', ylabel='function'>

# %%
sns.catplot(
    statistics,
    kind="bar",
    row='n_returns',
    y='function', 
    x='median_time',
    hue='use_numba', 
    log_scale=False
)

# %%
statistics[statistics.function == 'compute_sharpe_ratio']
# Out:
#                  function  use_numba  n_returns  min_time  max_time  \
# 96   compute_sharpe_ratio       True         10  0.000021  0.035707
# 97   compute_sharpe_ratio      False         10  0.000019  0.000311
# 98   compute_sharpe_ratio       True        100  0.000020  0.000094
# 99   compute_sharpe_ratio      False        100  0.000020  0.000076
# 100  compute_sharpe_ratio       True       1000  0.000022  0.000139
# 101  compute_sharpe_ratio      False       1000  0.000023  0.000792
# 102  compute_sharpe_ratio       True      10000  0.000041  0.000301
# 103  compute_sharpe_ratio      False      10000  0.000049  0.000298
#
#      mean_time  std_time  median_time  n_nans  n_tests  \
# 96    0.000167  0.002252     0.000023       0      250
# 97    0.000030  0.000034     0.000020       0      250
# 98    0.000023  0.000006     0.000022       0      250
# 99    0.000022  0.000006     0.000020       0      250
# 100   0.000026  0.000009     0.000024       0      250
# ...
