# %%
import pandas as pd
import seaborn as sns

statistics = pd.read_csv('results/benchmark_results-2025-07-30_11-26-43.csv')

# %%
sns.barplot(statistics, y='function', x='median_time', hue='n_returns', log_scale=False)
# Out:
# <Axes: xlabel='median_time', ylabel='function'>
